# %%
import matplotlib.pyplot as plt 
import numpy as np 
# import pandas as pd 
import matplotlib as mpl
import os
import json 
from scipy import optimize

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Scripts'

# %%
Results_dir = current_dir+'/../Results/'
Sims_dir = Results_dir + 'Wrapping_single_convergence/'

# %%
dir_list = os.listdir(Sims_dir)

# %%
Sim = Sims_dir+"Bending_10.0000_0.0000_Area_constraint_100000.0000_50.1663_Volume_constraint_100000.0000_33.3189_Bead_radius_0.3000_Frenkel_Normal_nopush_str_200.0000_Switch_IpOpt_Switch_Save_all_Switch_No_remesh_Nsim_1/"

# %%
Output = np.loadtxt(Sim+"Output_data.txt", skiprows=1)

Time = Output[:,0]
Volume = Output[:,1]
Area = Output[:,2]
Bending_energy = Output[:,3]
Area_constraint = Output[:,4]
Volume_constraint = Output[:,5]
Bead = Output[:,6]
TotalEnergy = Output[:,7]
Grad_norm = Output[:,12]

# %%
plt.plot(Time, Volume/33.32, label='Volume over target volume')
plt.legend()
plt.show()
plt.plot(Time, Area/(50.1663), label='Area over target area')
plt.legend()
plt.show()

# %%
plt.plot(Time[-1000:], Bending_energy[-1000:], label='Bending energy')
plt.xlabel('Time')
plt.ylabel('Bending energy')
plt.legend()
plt.show()

# %%
plt.plot(Time,Grad_norm)
plt.yscale('log')
plt.xlabel('Time')
plt.ylabel('Gradient norm')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
plt.scatter(Time[-1000:],Grad_norm[-1000:], label='Gradient norm')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Gradient norm')
plt.yscale('log')
plt.show()

# %%
dE = []
for i in range(999):
    dE.append( (TotalEnergy[-1000+i+1]-TotalEnergy[-1000+i])) #np.max([TotalEnergy[-1000+i+1],TotalEnergy[-1000+i]]) 


dE_eff =[]
for i in range(len(TotalEnergy)-1):
    dE_eff.append((TotalEnergy[i+1]-TotalEnergy[i])/50.0 )

# %%
plt.scatter(Time[-1000:-1], dE, label='Change in total energy')
plt.ylabel('Change in total energy')
# Out:
# Text(0, 0.5, 'Change in total energy')

# %%
plt.plot(dE_eff, label='averageChange in total energy')

# %%
plt.plot(Time, TotalEnergy, label='Change in total energy')
