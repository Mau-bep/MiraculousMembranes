# %%
import matplotlib.pyplot as plt 
import numpy as np 

import os
import json

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/home/mrojasve/Documents/DDG/MiraculousMembranes'

# %%
Results_dir = current_dir+'/projects/geometric-flow/Results/'
Sims_dir = Results_dir + '/One_bead_trials/'

# %%
Results_dir
# Out:
# '/home/mrojasve/Documents/DDG/MiraculousMembranes/../Results/'

# %%
Sim_path = Sims_dir + '/1/'

Output = Sim_path + 'Output_data.txt'
Data = np.loadtxt(Output,skiprows=1)


plt.plot(Data[:,0],Data[:,1],'b-')

# %%
V = np.pi*4/3

A = [9*V*V/(4*np.pi*np.pi *nu) for nu in np.linspace(0,1,100)]
# Out:
# /tmp/ipykernel_19629/3709630917.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   A = [9*V*V/(4*np.pi*np.pi *nu) for nu in np.linspace(0,1,100)]

# %%
plt.plot(np.linspace(0,1,100),A)
plt.xlim(0.2,1.0)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
Sims_dir = Results_dir + '/Cil_to_sphere_oct/'

# %%
Sim_path = Sims_dir + '/4/'

Output = Sim_path + 'Output_data.txt'
Data = np.loadtxt(Output,skiprows=1)


plt.clf()
plt.plot(Data[:,3],label='Bending')
plt.plot(Data[:,4],label='Surface tension')
plt.plot(Data[:,5],label='Volume_const')
plt.plot(Data[:,6],label='Edge_reg')
plt.legend()


plt.show()

plt.plot(Data[:,8],label='Bending')
plt.plot(Data[:,9],label='Surface tension')
# plt.plot(Data[:,10],label='Volume_const')
# plt.plot(Data[:,11],label='Edge_reg')
plt.legend()
plt.yscale('log')

# %%
def reduced_vol(V,A):
    return 3*V/(4*np.pi*(A/(4*np.pi))**(3/2))

# %%
reduced_vol(2.14146, 10.5004)
# Out:
# 0.6693101151516528

# %%
np.cos(0.3)*1.7
# Out:
# np.float64(1.6240720315135302)

# %%
np.sin(0.3)*1.7
# Out:
# np.float64(0.5023843513242772)

# %%
Sims_dir = Results_dir + 'Mem_shape_new'

# %%
Sims_dir
# Out:
# '/home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new'

# %%
Sim_path = Sims_dir + '/32/'
Sim_path = Sims_dir + '/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/'
print(Sim_path)
Output = Sim_path + 'Output_data.txt'
print("The output is \n {} \n isnt it?".format(Output))
Data = np.loadtxt(Output,skiprows=1)


plt.clf()
plt.plot(Data[:,3],label='Bending')
plt.plot(Data[:,4],label='Volume_const')
# plt.plot(Data[:,5],label='Area_const')
plt.plot(Data[:,5],label='Edge_reg')
plt.yscale('log')
plt.legend()


plt.show()

plt.plot(Data[:,7],label='Bending')
plt.plot(Data[:,8],label='Volume_const')
# plt.plot(Data[:,10],label='AREA_const')
plt.plot(Data[:,9],label='Edge_reg')
plt.legend()
plt.yscale('log')
# Out:
# /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/
# The output is
#  /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/Output_data.txt
#  isnt it?

# %%
Sim_path = Sims_dir + '/32/'
Sim_path = Sims_dir + '/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_10000.0000_3.5871_1.0000_-0.0001_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/'
print(Sim_path)
Output = Sim_path + 'Output_data.txt'
print("The output is \n {} \n isnt it?".format(Output))
Data = np.loadtxt(Output,skiprows=1)


plt.clf()
plt.plot(Data[:,3],label='Bending')
plt.plot(Data[:,4],label='Volume_const')
plt.plot(Data[:,5],label='Area_const')
plt.plot(Data[:,6],label='Edge_reg')
plt.yscale('log')
plt.legend()


plt.show()

plt.plot(Data[:,8],label='Bending')
plt.plot(Data[:,9],label='Volume_const')
plt.plot(Data[:,10],label='AREA_const')
plt.plot(Data[:,11],label='Edge_reg')
plt.legend()
plt.yscale('log')
# Out:
# /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_10000.0000_3.5871_1.0000_-0.0001_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/
# The output is
#  /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_10000.0000_3.5871_1.0000_-0.0001_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Nsim_1/Output_data.txt
#  isnt it?

# %%
Sim_path = Sims_dir + '/32/'
Sim_path = Sims_dir + '/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_100000.0000_3.5862_1.0000_-0.0010_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Switch_Save_all_Nsim_1/'
print(Sim_path)
Output = Sim_path + 'Output_data.txt'
print("The output is \n {} \n isnt it?".format(Output))
Data = np.loadtxt(Output,skiprows=1)


plt.clf()
plt.plot(Data[:,3],label='Bending')
plt.plot(Data[:,4],label='Volume_const')
plt.plot(Data[:,5],label='Area_const')
plt.plot(Data[:,6],label='Edge_reg')
plt.yscale('log')
plt.legend()


plt.show()

plt.plot(Data[:,8],label='Bending')
plt.plot(Data[:,9],label='Volume_const')
plt.plot(Data[:,10],label='AREA_const')
plt.plot(Data[:,11],label='Edge_reg')
plt.legend()
plt.yscale('log')
# Out:
# /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_100000.0000_3.5862_1.0000_-0.0010_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Switch_Save_all_Nsim_1/
# The output is
#  /home/mrojasve/Documents/DDG/MiraculousMembranes/projects/geometric-flow/Results/Mem_shape_new/Bending_10.0000_0.0000_Volume_constraint_10000.0000_0.5532_Area_constraint_100000.0000_3.5862_1.0000_-0.0010_Edge_reg_0.0000_Switch_Newton_Switch_No_remesh_Switch_Save_all_Nsim_1/Output_data.txt
#  isnt it?
